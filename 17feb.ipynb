# %%
x = int(input('enter any number: '))
# Out:
# enter any number:  12

# %%
x
# Out:
# 12

# %%
factors_cnt = 0

# %%
for i in range(1, x+1):
    if(x%i == 0):
        factors_cnt = factors_cnt+1
if factors_cnt == 2:
    print("number is prime")
else:
    print("not prime")
# Out:
# not prime

# %%
l = [1,2,6,3,2,1,3,6,4,3,2,3,1]
string = "gfshtrjhsfghuokjdtfuinbvsertg"
l.count(3)
# Out:
# 4

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
for i in l:
    d[i] =l.count(i)

# %%
seen_numbers = []

# %%
for i in l:
    if i not in seen_numbers:
        d[i] = l.count(i)
        seen_numbers.append(i)

# %%
l = [1,2,2,3,3,4,1,2]
output=[1,'one',2,2,1,'one',3,4,1,'one',2]

# %% [raw]
# 'abc'
# abc
# acb
# bac
# bca
# cba
# cab

# %%
import itertools

# %%
dir(itertools)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_grouper',
#  '_tee',
#  '_tee_dataobject',
#  'accumulate',
#  'batched',
#  'chain',
#  'combinations',
#  'combinations_with_replacement',
#  'compress',
#  'count',
#  'cycle',
#  'dropwhile',
#  'filterfalse',
#  'groupby',
#  'islice',
#  'pairwise',
#  'permutations',
#  'product',
#  'repeat',
#  'starmap',
#  'takewhile',
#  'tee',
#  'zip_longest']
