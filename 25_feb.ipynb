# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ocutils (C:\Users\hp\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ocutils (C:\Users\hp\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ocutils (C:\Users\hp\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
corpus="""Hello It's Karina Yadav , Today my plan was to sleep but they told us that we have 
review so I came but there isn't any!"""

# %%
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello It's Karina Yadav , Today my plan was to sleep but they told us that we have
# review so I came but there isn't any!

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'It',
#  "'s",
#  'Karina',
#  'Yadav',
#  ',',
#  'Today',
#  'my',
#  'plan',
#  'was',
#  'to',
#  'sleep',
#  'but',
#  'they',
#  'told',
#  'us',
#  'that',
#  'we',
#  'have',
#  'review',
#  'so',
#  'I',
#  'came',
#  'but',
#  'there',
#  'is',
#  "n't",
#  'any',
#  '!']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'It', "'s", 'Karina', 'Yadav', ',', 'Today', 'my', 'plan', 'was', 'to', 'sleep', 'but', 'they', 'told', 'us', 'that', 'we', 'have', 'review', 'so', 'I', 'came', 'but', 'there', 'is', "n't", 'any', '!']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
##########STEMMING

# %% [markdown]
# from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()

# %%
for word in words:

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %%
###RegexpStemmer class
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing$|s$|e$|able$',min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %%
###Snowball Stemmer
It is a stemming algorithm which is also known as the Porter2 stemming algorithm as
it is a better version of the Porter since some issues of it were fixed in the stemmer

# %%
from nltk.stem import SnowballStemmer

# %%
snowballsstemmer=SnowballStemmer('english')

# %%
for word in words:
    print(word+"---->"+snowballsstemmer.stem(word))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 for word in words:
#       2     print(word+"---->"+snowballsstemmer.stem(word))
#
# NameError: name 'words' is not defined

# %%
stemming.stem("fairly"),stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowballsstemmer.stem("fairly"),snowballsstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
snowballsstemmer.stem('goes')
# Out:
# 'goe'

# %%
stemming.stem('goes')
# Out:
# 'goe'

# %%
###Wordnet Lemmatizer
The output we will get after lemmatization is called 'lemma'

# %%
from nltk.stem import WORDNETLemmatizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 from nltk.stem import WORDNETLemmatizer
#
# ImportError: cannot import name 'WORDNETLemmatizer' from 'nltk.stem' (C:\Users\hp\anaconda3\Lib\site-packages\nltk\stem\__init__.py)
